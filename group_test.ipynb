# %%
import pandas as pd
import group_recommender_algs as gra

ratings_data = pd.read_csv("Dataset/last/XWines_Slim_150K_ratings.csv")
wine_data = pd.read_csv("Dataset/last/XWines_Slim_1K_wines.csv")
merged_data = pd.merge(ratings_data, wine_data, on='WineID')
wine_data = gra.avg_ratings(wine_data,ratings_data)
group_data = pd.read_csv("Dataset/last/group_composition.csv")
# Out:
# /var/folders/8_/f8kmzr5j715637z3t60_pjqm0000gn/T/ipykernel_7509/4261622503.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratings_data = pd.read_csv("Dataset/last/XWines_Slim_150K_ratings.csv")

# %%
group_id = 1

# %%
group_info = group_data[group_data['group_id'] == group_id].iloc[0]
group_members = eval(group_info['group_members']) 
display(group_info)
# Out:
# Unnamed: 0                           1
# group_id                             1
# group_size                           2
# group_similarity                random
# group_members       [1180876, 1006585]
# avg_similarity                -0.01537
# Name: 1, dtype: object

# %%
group_ratings = ratings_data[ratings_data['UserID'].isin(group_members)]
display(group_ratings.sort_values(by=['UserID', 'Rating'], ascending=[True, False]))
# Out:
#         RatingID   UserID  WineID Vintage  Rating                 Date
# 4973      229308  1006585  111422    1996     5.0  2019-05-06 09:54:16
# 11619     692236  1006585  111544    2004     5.0  2017-05-17 06:02:23
# 95749   13088269  1006585  116995    2016     5.0  2017-03-24 21:11:17
# 1559       74982  1006585  111516    1984     4.5  2017-02-18 14:01:50
# 4874      224110  1006585  111434    1996     4.5  2017-02-25 21:11:50
# 9125      509921  1006585  112834    2002     4.5  2016-08-15 17:39:09
# 11091     650029  1006585  115984    2004     4.5  2016-03-02 19:50:15
# 62513    8111255  1006585  101677    2014     4.5  2017-05-05 08:55:26
# 64357    8360500  1006585  113600    2014     4.5  2015-10-02 16:45:29
# 91668   12440902  1006585  113913    2016     4.5  2017-04-17 19:52:41
# 65325    8488467  1006585  111471    2014     4.0  2017-03-24 20:35:46
# 95189   12997339  1006585  102448    2016     4.0  2017-05-05 09:43:13
# 142517  20670511  1006585  113321    N.V.     4.0  2017-03-09 18:35:28
# 95133   12988704  1006585  113489    2016     3.5  2017-05-05 19:41:45
# 22266    1989629  1180876  111521    2009     4.5  2018-07-21 17:16:33
# 45617    5533536  1180876  162507    2012     4.5  2017-08-19 23:24:26
# 105527  14657938  1180876  167443    2017     4.5  2021-10-15 17:45:18
# 140706  20587848  1180876  111479    N.V.     4.5  2020-07-26 15:23:28
# 44533    5353188  1180876  167429    2012     4.0  2017-01-14 22:49:27
# 50682    6403303  1180876  101610    2013     4.0  2019-08-14 19:30:25
# 62374    8096211  1180876  167449    2014     4.0  2017-05-22 22:50:46
# 63274    8216556  1180876  167431    2014     4.0  2016-05-02 00:11:53
# 106302  14765329  1180876  162506    2017     4.0  2020-01-01 01:58:03
# 144423  20760117  1180876  101847    N.V.     4.0  2021-12-03 20:14:00
# 52435    6668697  1180876  167470    2013     3.5  2016-10-16 22:18:02
# 97894   13449525  1180876  162519    2016     3.5  2018-12-05 19:02:25
# 104092  14453914  1180876  101584    2017     3.5  2018-12-26 21:52:50
# 106527  14798794  1180876  111398    2017     3.5  2018-10-31 19:09:18
# 145046  20788749  1180876  100014    N.V.     3.5  2021-12-08 19:42:35
# 19038    1513450  1180876  115267    2008     3.0  2014-01-01 02:09:07
# 36444    4108996  1180876  167614    2011     3.0  2013-07-12 00:00:17

# %%
recommended_wines = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, None)
display(recommended_wines)
# Out:
#      WineID                                           WineName       Type  \
# 258  112084                          Oenothèque Brut Champagne  Sparkling
# 445  141193                                  Brachetto d'Acqui  Sparkling
# 297  112834                    Dom Ruinart Rosé Brut Champagne  Sparkling
# 350  115984  Comtesse Marie de France Brut Millésime Champa...  Sparkling
# 323  113321  V.O. Version Originale Blanc de Blancs Extra B...  Sparkling
#
#             Elaborate                        Grapes  \
# 258  Assemblage/Blend  ['Pinot Noir', 'Chardonnay']
# 445     Varietal/100%                 ['Brachetto']
# 297     Varietal/100%                ['Chardonnay']
# 350  Assemblage/Blend  ['Chardonnay', 'Pinot Noir']
# 323     Varietal/100%                ['Chardonnay']
#
#                                              Harmonize   ABV           Body  \
# 258  ['Pork', 'Rich Fish', 'Shellfish', 'Soft Cheese']  12.5  Medium-bodied
# 445   ['Appetizer', 'Snack', 'Fruit', 'Cake', 'Cream']   6.0  Medium-bodied
# 297  ['Pork', 'Rich Fish', 'Shellfish', 'Soft Cheese']  12.5  Medium-bodied
# 350  ['Pork', 'Rich Fish', 'Shellfish', 'Soft Cheese']  12.5  Medium-bodied
# 323  ['Pork', 'Rich Fish', 'Shellfish', 'Soft Cheese']  12.0  Medium-bodied
#
#     Acidity Code Country  RegionID                   RegionName  WineryID  \
# 258    High   FR  France      1188                    Champagne     21604
# 445    High   IT   Italy      1528            Brachetto d'Acqui     40964
# 297    High   FR  France      1188                    Champagne     20584
# 350    High   FR  France      1193  Champagne Grand Cru 'Bouzy'     22124
# 323    High   FR  France      1188                    Champagne     21583
#
#           WineryName                           Website  \
# 258     Dom Pérignon       https://www.domperignon.com
# 445     Il Falchetto        http://www.ilfalchetto.com
# 297          Ruinart            http://www.ruinart.com
# 350        Paul Bara  http://www.champagnepaulbara.com
# 323  Jacques Selosse  http://www.selosse-lesavises.com
#
#                                               Vintages  AvgRating
# 258  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.757212
# 445  [2022, 2021, 2020, 2019, 2018, 2017, 2016, 201...   4.666667
# 297  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.459016
# 350  [2020, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.423077
# 323  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.419643

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.item_knn import ItemItem

itemitem = ItemItem(15, min_nbrs=3)  
recsys_item = Recommender.adapt(itemitem)
recsys_item.fit(merged_data.rename(columns={'UserID':'user','WineID':'item','Rating':'rating'}))
# Out:
# Numba is using threading layer workqueue - consider TBB
# found 1 potential runtime problems - see https://boi.st/lkpy-perf
# /Users/irinaruzavina/Library/Python/3.9/lib/python/site-packages/lenskit/algorithms/item_knn.py:119: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   b = blocks[bi]

# %%
recommended_wines_item = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, recsys_item)
display(recommended_wines_item)
# Out:
#      WineID                              WineName     Type         Elaborate  \
# 481  144337       Tre Soli Tre Grappa Invecchiata  Dessert     Varietal/100%
# 528  155628                   Don PX Gran Reserva  Dessert     Varietal/100%
# 508  153536  Grappa di Amarone della Valpolicella  Dessert  Assemblage/Blend
# 209  111478  Sauternes (Premier Grand Cru Classé)  Dessert  Assemblage/Blend
# 892  192645                      Riesling Icewine  Dessert     Varietal/100%
#
#                                     Grapes  \
# 481                           ['Nebbiolo']
# 528                      ['Pedro Ximenez']
# 508  ['Corvina', 'Rondinella', 'Molinara']
# 209        ['Sémillon', 'Sauvignon Blanc']
# 892                           ['Riesling']
#
#                                   Harmonize   ABV         Body Acidity Code  \
# 481  ['Beef', 'Pasta', 'Lamb', 'Game Meat']  43.0  Full-bodied    High   IT
# 528        ['Sweet Dessert', 'Blue Cheese']  17.0  Full-bodied     Low   ES
# 508          ['Chocolate', 'Sweet Dessert']  43.0  Full-bodied    High   IT
# 209        ['Fruit Dessert', 'Blue Cheese']  13.5  Full-bodied    High   FR
# 892        ['Sweet Dessert', 'Soft Cheese']   9.5  Full-bodied    High   CA
#
#     Country  RegionID        RegionName  WineryID         WineryName  \
# 481   Italy      1655          Piemonte     45593              Berta
# 528   Spain      1994  Montilla-Moriles     36405        Toro Albalá
# 508   Italy      1713      Valpolicella     44939            Tommasi
# 209  France      1455         Sauternes     32311  Château Suduiraut
# 892  Canada      2208   Okanagan Valley     66001           Sandhill
#
#                              Website  \
# 481  https://www.distillerieberta.it
# 528        http://www.toroalbala.com
# 508           http://www.tommasi.com
# 209         http://www.suduiraut.com
# 892      http://www.sandhillwines.ca
#
#                                               Vintages  AvgRating
# 481  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.794118
# 528  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.355392
# 508  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.333333
# 209  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.298541
# 892  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.125000

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.user_knn import UserUser

useruser = UserUser(15, min_nbrs=3)  
recsys_user = Recommender.adapt(useruser)
recsys_user.fit(merged_data.rename(columns={'UserID':'user','WineID':'item','Rating':'rating'}))

# %%
recommended_wines_user = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, recsys_user)
display(recommended_wines_user)
# Out:
#      WineID                              WineName     Type         Elaborate  \
# 481  144337       Tre Soli Tre Grappa Invecchiata  Dessert     Varietal/100%
# 528  155628                   Don PX Gran Reserva  Dessert     Varietal/100%
# 508  153536  Grappa di Amarone della Valpolicella  Dessert  Assemblage/Blend
# 209  111478  Sauternes (Premier Grand Cru Classé)  Dessert  Assemblage/Blend
# 892  192645                      Riesling Icewine  Dessert     Varietal/100%
#
#                                     Grapes  \
# 481                           ['Nebbiolo']
# 528                      ['Pedro Ximenez']
# 508  ['Corvina', 'Rondinella', 'Molinara']
# 209        ['Sémillon', 'Sauvignon Blanc']
# 892                           ['Riesling']
#
#                                   Harmonize   ABV         Body Acidity Code  \
# 481  ['Beef', 'Pasta', 'Lamb', 'Game Meat']  43.0  Full-bodied    High   IT
# 528        ['Sweet Dessert', 'Blue Cheese']  17.0  Full-bodied     Low   ES
# 508          ['Chocolate', 'Sweet Dessert']  43.0  Full-bodied    High   IT
# 209        ['Fruit Dessert', 'Blue Cheese']  13.5  Full-bodied    High   FR
# 892        ['Sweet Dessert', 'Soft Cheese']   9.5  Full-bodied    High   CA
#
#     Country  RegionID        RegionName  WineryID         WineryName  \
# 481   Italy      1655          Piemonte     45593              Berta
# 528   Spain      1994  Montilla-Moriles     36405        Toro Albalá
# 508   Italy      1713      Valpolicella     44939            Tommasi
# 209  France      1455         Sauternes     32311  Château Suduiraut
# 892  Canada      2208   Okanagan Valley     66001           Sandhill
#
#                              Website  \
# 481  https://www.distillerieberta.it
# 528        http://www.toroalbala.com
# 508           http://www.tommasi.com
# 209         http://www.suduiraut.com
# 892      http://www.sandhillwines.ca
#
#                                               Vintages  AvgRating
# 481  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.794118
# 528  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.355392
# 508  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.333333
# 209  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.298541
# 892  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.125000
