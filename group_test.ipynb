# %%
import pandas as pd
import group_recommender_algs as gra

ratings_data = pd.read_csv("Dataset/last/XWines_Slim_150K_ratings.csv")
wine_data = pd.read_csv("Dataset/last/XWines_Slim_1K_wines.csv")
merged_data = pd.merge(ratings_data, wine_data, on='WineID')
wine_data = gra.avg_ratings(wine_data,ratings_data)
group_data = pd.read_csv("Dataset/last/group_composition.csv")
# Out:
# /var/folders/8_/f8kmzr5j715637z3t60_pjqm0000gn/T/ipykernel_1903/4261622503.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratings_data = pd.read_csv("Dataset/last/XWines_Slim_150K_ratings.csv")

# %%
group_id = 10

# %%
recommended_wines = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, None)
display(recommended_wines)
# Out:
#        WineID                             WineName Type         Elaborate  \
# 819  181199.0                   Lauréne Pinot Noir  Red     Varietal/100%
# 820  181203.0                           Pinot Noir  Red     Varietal/100%
# 435  140273.0  Vigneto Bellavista Chianti Classico  Red  Assemblage/Blend
# 414  138475.0               Duemani Cabernet Franc  Red     Varietal/100%
# 570  162721.0                   Espiritu de Apalta  Red     Varietal/100%
#
#                               Grapes  \
# 819                   ['Pinot Noir']
# 820                   ['Pinot Noir']
# 435  ['Sangiovese', 'Malvasia Nera']
# 414               ['Cabernet Franc']
# 570           ['Cabernet Sauvignon']
#
#                                              Harmonize   ABV           Body  \
# 819           ['Beef', 'Veal', 'Game Meat', 'Poultry']  14.0  Medium-bodied
# 820           ['Beef', 'Veal', 'Game Meat', 'Poultry']  14.5  Medium-bodied
# 435                        ['Beef', 'Veal', 'Poultry']  13.0  Medium-bodied
# 414  ['Beef', 'Lamb', 'Veal', 'Poultry', 'Cured Meat']  14.5  Medium-bodied
# 570               ['Beef', 'Pasta', 'Veal', 'Poultry']  13.5  Medium-bodied
#
#     Acidity Code        Country  RegionID            RegionName  WineryID  \
# 819    High   US  United States    1788.0          Dundee Hills   55339.0
# 820    High   US  United States    1879.0  Russian River Valley   54014.0
# 435    High   IT          Italy    1699.0               Toscana   42434.0
# 414  Medium   IT          Italy    1574.0         Costa Toscana   42716.0
# 570    High   CL          Chile    2268.0      Colchagua Valley   39723.0
#
#           WineryName                        Website  \
# 819  Domaine Drouhin  http://www.domainedrouhin.com
# 820       Juggernaut    https://juggernautwines.com
# 435  Castello di Ama   http://www.castellodiama.com
# 414          Duemani          http://www.duemani.eu
# 570            Neyen            http://www.neyen.cl
#
#                                               Vintages  AvgRating
# 819  [2022, 2021, 2020, 2019, 2018, 2017, 2016, 201...   4.794118
# 820  [2022, 2021, 2020, 2019, 2018, 2017, 2016, 201...   4.500000
# 435  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.452381
# 414  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.365217
# 570  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.307087

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.item_knn import ItemItem

itemitem = ItemItem(15, min_nbrs=3)  
recsys_item = Recommender.adapt(itemitem)
recsys_item.fit(merged_data.rename(columns={'UserID':'user','WineID':'item','Rating':'rating'}))
# Out:
# Numba is using threading layer workqueue - consider TBB
# found 1 potential runtime problems - see https://boi.st/lkpy-perf
# /Users/irinaruzavina/Library/Python/3.9/lib/python/site-packages/lenskit/algorithms/item_knn.py:119: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   b = blocks[bi]

# %%
recommended_wines_item = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, recsys_item)
display(recommended_wines_item)
# Out:
#        WineID                                           WineName     Type  \
# 941  194674.0                                   Aszú 6 Puttonyos  Dessert
# 968  196091.0               Tokaji Muscat Lunel Aszu 6 Puttonyos  Dessert
# 555  162455.0  Muscat White South Coast (Мускат Белый Южнобер...  Dessert
# 420  138829.0                     Vin Santo del Chianti Classico  Dessert
# 942  194769.0                            Tokaji Aszú 3 Puttonyos  Dessert
#
#             Elaborate                                   Grapes  \
# 941     Varietal/100%                              ['Furmint']
# 968     Varietal/100%                         ['Muscat Blanc']
# 555     Varietal/100%                         ['Muscat Blanc']
# 420  Assemblage/Blend  ['Sangiovese', 'Malvasia', 'Trebbiano']
# 942     Varietal/100%                              ['Furmint']
#
#                                              Harmonize   ABV           Body  \
# 941                   ['Sweet Dessert', 'Blue Cheese']  10.0  Medium-bodied
# 968                   ['Sweet Dessert', 'Blue Cheese']  11.4  Medium-bodied
# 555                    ['Spicy Food', 'Sweet Dessert']  16.0  Medium-bodied
# 420  ['Beef', 'Lamb', 'Veal', 'Pork', 'Game Meat', ...  15.0  Medium-bodied
# 942                   ['Sweet Dessert', 'Blue Cheese']  10.0  Medium-bodied
#
#     Acidity Code  Country  RegionID                      RegionName  WineryID  \
# 941    High   HU  Hungary    2413.0                           Tokaj   68119.0
# 968    High   HU  Hungary    2413.0                           Tokaj   68177.0
# 555    High   UA  Ukraine    2567.0                  Crimeia (Крим)   52590.0
# 420    High   IT    Italy    3005.0  Vin Santo del Chianti Classico   49419.0
# 942    High   HU  Hungary    2413.0                           Tokaj   68165.0
#
#                 WineryName                       Website  \
# 941                 Megyer  http://www.pajzos-megyer.com
# 968  Pauleczki Szolobirtok          www.pauleczki-vin.hu
# 555  Massandra (Массандра)    http://www.massandra.co.uk
# 420                Fèlsina         http://www.felsina.it
# 942         Château Pajzos         http://www.pajzos.com
#
#                                               Vintages  AvgRating
# 941  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.555556
# 968  [2020, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.222222
# 555  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   4.153846
# 420  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.126374
# 942  [2021, 2020, 2017, 2016, 2015, 2014, 2013, 201...   4.050847

# %%
from lenskit.algorithms import Recommender
from lenskit.algorithms.user_knn import UserUser

useruser = UserUser(15, min_nbrs=3)  
recsys_user = Recommender.adapt(useruser)
recsys_user.fit(merged_data.rename(columns={'UserID':'user','WineID':'item','Rating':'rating'}))

# %%
recommended_wines_user = gra.group_rec(group_id, group_data, merged_data,wine_data,ratings_data, recsys_user)
display(recommended_wines_user)
# Out:
#        WineID                                 WineName   Type      Elaborate  \
# 174  108976.0  Bernkasteler Badstube Riesling Spätlese  White  Varietal/100%
# 175  109250.0                    Nackenheim Rothenberg  White  Varietal/100%
# 911  193486.0                          Sauvignon Blanc  White  Varietal/100%
# 687  171001.0          Life from Stone Sauvignon Blanc  White  Varietal/100%
# 116  105032.0                             Diga? Branco  White  Varietal/100%
#
#                   Grapes                                          Harmonize  \
# 174         ['Riesling']  ['Pork', 'Shellfish', 'Spicy Food', 'Poultry',...
# 175         ['Riesling']  ['Pork', 'Shellfish', 'Spicy Food', 'Poultry',...
# 911  ['Sauvignon Blanc']         ['Shellfish', 'Vegetarian', 'Goat Cheese']
# 687  ['Sauvignon Blanc']         ['Shellfish', 'Vegetarian', 'Goat Cheese']
# 116         ['Viognier']  ['Shellfish', 'Appetizer', 'Snack', 'Lean Fish...
#
#       ABV          Body Acidity Code       Country  RegionID   RegionName  \
# 174   8.5  Light-bodied    High   DE       Germany    1081.0        Mosel
# 175  13.0  Light-bodied    High   DE       Germany    1105.0  Rheinhessen
# 911  13.0  Light-bodied    High   NZ   New Zealand    2485.0  Marlborough
# 687  12.5  Light-bodied    High   ZA  South Africa    2616.0    Robertson
# 116  13.5  Light-bodied    High   PT      Portugal    1046.0     Bairrada
#
#      WineryID          WineryName                           Website  \
# 174   13521.0       Selbach-Oster       http://www.selbach-oster.de
# 175   15380.0  Weingut Gunderloch          http://www.gunderloch.de
# 911   69201.0          Whitehaven           http://whitehaven.co.nz
# 687   70862.0  Springfield Estate  http://www.springfieldestate.com
# 116   12633.0          Campolargo   http://www.campolargovinhos.com
#
#                                               Vintages  AvgRating
# 174  [2020, 2019, 2018, 2017, 2016, 2015, 2014, 201...   4.250000
# 175  [2020, 2018, 2017, 2016, 2015, 2014, 2013, 201...   4.090909
# 911  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   3.956473
# 687  [2021, 2020, 2019, 2018, 2017, 2016, 2015, 201...   3.955882
# 116  [2019, 2018, 2017, 2016, 2015, 2014, 2013, 201...   3.933333
