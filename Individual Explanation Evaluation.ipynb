# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

metrics_df = pd.read_csv("user_explanation_metrics.csv")
metrics_df.head()
# Out:
#     UserID  Acceptance Rate  Satisfaction Score  Coverage  \
# 0  1356810              0.0                 NaN       0.0
# 1  1164877              0.0                 NaN       0.0
# 2  1211463              0.0                 NaN       0.0
# 3  1076348              0.0                 NaN       0.0
# 4  1126910              0.0                 NaN       0.0
#
#    Explanation Coherence  Diversity
# 0               0.087559        1.0
# 1               0.084973        1.0
# 2               0.084659        1.0
# 3               0.065642        1.0
# 4               0.087092        1.0

# %%
metrics_to_plot = ['Acceptance Rate', 'Satisfaction Score', 'Coverage', 'Explanation Coherence', 'Diversity']

for metric in metrics_to_plot:
    plt.figure(figsize=(8, 4))
    sns.histplot(metrics_df[metric], bins=20, kde=True, color='skyblue')
    plt.title(f'Distribution of {metric} Across All Users')
    plt.xlabel(metric)
    plt.ylabel('Frequency')
    plt.grid(axis='y')
    plt.savefig(f'/Histograms/hist_{metric}.png')
    plt.show()
